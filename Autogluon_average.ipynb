# %% [markdown]
# # import / 라이브러리 호출

# %%
import pandas as pd
import random
import os
import numpy as np

from sklearn.preprocessing import LabelEncoder
from autogluon.tabular import TabularDataset, TabularPredictor
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Fixed RandomSeed / 랜덤시드 고정
#
# seed를 고정하지 않는다면 같은 코드라도 매번 다른 결과가 나오게됩니다.
#
# 항상 동일한 결과를 얻기 위해서 사용합니다.

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(1994) # Seed 고정

# %% [markdown]
# # Data Load / 데이터 불러오기

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.head()
# Out:
#            ID  추석까지 남은 기간(주)  쇼핑몰 구분   가격(원)  프로모션 여부  도시 유형 지역 유형    쇼핑몰 유형
# 0  TRAIN_0000              1  쇼핑몰 15  212000        0   도시 6  지역 1  쇼핑몰 유형 2  \
# 1  TRAIN_0001              2  쇼핑몰 72  113000        0  도시 21  지역 1  쇼핑몰 유형 1
# 2  TRAIN_0002              0  쇼핑몰 15   67000        0   도시 6  지역 1  쇼핑몰 유형 2
# 3  TRAIN_0003              1  쇼핑몰 13  206000        0  도시 12  지역 3  쇼핑몰 유형 1
# 4  TRAIN_0004              1  쇼핑몰 65  140000        0  도시 16  지역 2  쇼핑몰 유형 2
#
#            선물 유형  수요량
# 0     명절혼합과일선물세트   28
# 1       발효홍삼선물세트   27
# 2       실속스팸선물세트  769
# 3  자연산프리미엄버섯선물세트   27
# 4      자연산새우선물세트  337

# %%
train_data = TabularDataset(train)
test_data = TabularDataset(test)

train_data.drop('ID',axis = 1, inplace = True)
test_data.drop('ID',axis = 1, inplace = True)


label = '수요량'
eval_metric = 'rmse'
time_limit = 3600*1

# %% [markdown]
# # Model fitting / 모델 학습

# %%
predictor = TabularPredictor(
    label=label, eval_metric=eval_metric
).fit(train_data, 
      presets='best_quality', 
      num_stack_levels=3,
      time_limit=time_limit, num_gpus=1)
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20230930_021527\"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=3, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "AutogluonModels\ag-20230930_021527\"
# AutoGluon Version:  0.6.0
# Python Version:     3.8.13
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# Train Data Rows:    5872
# Train Data Columns: 8
# Label Column: 수요량
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == int and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (4455, 13, 264.31369, 338.78921)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    55811.9 MB
# 	Train Data (Original)  Memory Usage: 2.93 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', [])    : 3 | ['추석까지 남은 기간(주)', '가격(원)', '프로모션 여부']
# 		('object', []) : 5 | ['쇼핑몰 구분', '도시 유형', '지역 유형', '쇼핑몰 유형', '선물 유형']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 5 | ['쇼핑몰 구분', '도시 유형', '지역 유형', '쇼핑몰 유형', '선물 유형']
# 		('int', [])       : 2 | ['추석까지 남은 기간(주)', '가격(원)']
# 		('int', ['bool']) : 1 | ['프로모션 여부']
# 	0.1s = Fit runtime
# 	8 features in original data used to generate 8 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.13 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.07s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# AutoGluon will fit 4 stack levels (L1 to L4) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 1199.68s of the 3599.93s of remaining time.
# 	-306.5886	 = Validation score   (-root_mean_squared_error)
# 	0.0s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 1199.06s of the 3599.31s of remaining time.
# 	-309.9456	 = Validation score   (-root_mean_squared_error)
# 	0.0s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1199.02s of the 3599.27s of remaining time.
# Will use sequential fold fitting strategy because import of ray failed. Reason: ray is required to train folds in parallel. A quick tip is to install via `pip install ray==2.0.0`, or use sequential fold fitting by passing `sequential_local` to `ag_args_ensemble` when calling tabular.fitFor example: `predictor.fit(..., ag_args_ensemble={'fold_fitting_strategy': 'sequential_local'})`
# 	Warning: Exception caused LightGBMXT_BAG_L1 to fail during training... Skipping this model.
# 		module 'pandas.core.strings' has no attribute 'StringMethods'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1422, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1367, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\abstract\abstract_model.py", line 628, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 154, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 236, in _fit
#     self._fit_folds(X=X, y=y, model_base=model_base, X_pseudo=X_pseudo, y_pseudo=y_pseudo,
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 500, in _fit_folds
#     fold_fitting_strategy = fold_fitting_strategy(**fold_fitting_strategy_args)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 148, in __init__
#     minimum_model_resources = self._initialized_model_base.get_minimum_resources(
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\tabular\models\lgb\lgb_model.py", line 352, in get_minimum_resources
#     if is_gpu_available and self._is_gpu_lgbm_installed():
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\tabular\models\lgb\lgb_model.py", line 336, in _is_gpu_lgbm_installed
#     try_import_lightgbm()
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\utils\try_import.py", line 157, in try_import_lightgbm
#     import lightgbm
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\basic.py", line 20, in <module>
#     from .compat import PANDAS_INSTALLED, concat, dt_DataTable, is_dtype_sparse, pd_DataFrame, pd_Series
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\compat.py", line 130, in <module>
#     from dask.dataframe import DataFrame as dask_DataFrame
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\__init__.py", line 3, in <module>
#     from . import backends, dispatch, rolling
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\backends.py", line 20, in <module>
#     from .core import DataFrame, Index, Scalar, Series, _Frame
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\core.py", line 52, in <module>
#     from .accessor import DatetimeAccessor, StringAccessor
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\accessor.py", line 109, in <module>
#     class StringAccessor(Accessor):
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\accessor.py", line 121, in StringAccessor
#     @derived_from(pd.core.strings.StringMethods)
# AttributeError: module 'pandas.core.strings' has no attribute 'StringMethods'
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 1198.74s of the 3598.99s of remaining time.
# 	Warning: Exception caused LightGBM_BAG_L1 to fail during training... Skipping this model.
# 		module 'pandas.core.strings' has no attribute 'StringMethods'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1422, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1367, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\abstract\abstract_model.py", line 628, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 154, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 236, in _fit
#     self._fit_folds(X=X, y=y, model_base=model_base, X_pseudo=X_pseudo, y_pseudo=y_pseudo,
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 500, in _fit_folds
#     fold_fitting_strategy = fold_fitting_strategy(**fold_fitting_strategy_args)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 148, in __init__
#     minimum_model_resources = self._initialized_model_base.get_minimum_resources(
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\tabular\models\lgb\lgb_model.py", line 352, in get_minimum_resources
#     if is_gpu_available and self._is_gpu_lgbm_installed():
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\tabular\models\lgb\lgb_model.py", line 336, in _is_gpu_lgbm_installed
#     try_import_lightgbm()
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\utils\try_import.py", line 157, in try_import_lightgbm
#     import lightgbm
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\basic.py", line 20, in <module>
#     from .compat import PANDAS_INSTALLED, concat, dt_DataTable, is_dtype_sparse, pd_DataFrame, pd_Series
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\compat.py", line 130, in <module>
#     from dask.dataframe import DataFrame as dask_DataFrame
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\__init__.py", line 3, in <module>
#     from . import backends, dispatch, rolling
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\backends.py", line 20, in <module>
#     from .core import DataFrame, Index, Scalar, Series, _Frame
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\core.py", line 52, in <module>
#     from .accessor import DatetimeAccessor, StringAccessor
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\accessor.py", line 109, in <module>
#     class StringAccessor(Accessor):
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\accessor.py", line 121, in StringAccessor
#     @derived_from(pd.core.strings.StringMethods)
# AttributeError: module 'pandas.core.strings' has no attribute 'StringMethods'
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 1198.72s of the 3598.97s of remaining time.
# 	-181.2584	 = Validation score   (-root_mean_squared_error)
# 	0.38s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1198.07s of the 3598.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	Warning: Exception caused CatBoost_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		`import catboost` failed. A quick tip is to install via `pip install autogluon.tabular[catboost]==0.6.0`.
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 1198.05s of the 3598.3s of remaining time.
# 	-201.3688	 = Validation score   (-root_mean_squared_error)
# 	0.32s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1197.46s of the 3597.71s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-132.6892	 = Validation score   (-root_mean_squared_error)
# 	28.69s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1168.26s of the 3568.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-156.5765	 = Validation score   (-root_mean_squared_error)
# 	55.24s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1112.43s of the 3512.68s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-146.2008	 = Validation score   (-root_mean_squared_error)
# 	228.58s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 883.44s of the 3283.69s of remaining time.
# 	Warning: Exception caused LightGBMLarge_BAG_L1 to fail during training... Skipping this model.
# 		module 'pandas.core.strings' has no attribute 'StringMethods'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1422, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1367, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\abstract\abstract_model.py", line 628, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 154, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 236, in _fit
#     self._fit_folds(X=X, y=y, model_base=model_base, X_pseudo=X_pseudo, y_pseudo=y_pseudo,
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 500, in _fit_folds
#     fold_fitting_strategy = fold_fitting_strategy(**fold_fitting_strategy_args)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 148, in __init__
#     minimum_model_resources = self._initialized_model_base.get_minimum_resources(
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\tabular\models\lgb\lgb_model.py", line 352, in get_minimum_resources
#     if is_gpu_available and self._is_gpu_lgbm_installed():
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\tabular\models\lgb\lgb_model.py", line 336, in _is_gpu_lgbm_installed
#     try_import_lightgbm()
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\utils\try_import.py", line 157, in try_import_lightgbm
#     import lightgbm
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\basic.py", line 20, in <module>
#     from .compat import PANDAS_INSTALLED, concat, dt_DataTable, is_dtype_sparse, pd_DataFrame, pd_Series
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\compat.py", line 130, in <module>
#     from dask.dataframe import DataFrame as dask_DataFrame
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\__init__.py", line 3, in <module>
#     from . import backends, dispatch, rolling
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\backends.py", line 20, in <module>
#     from .core import DataFrame, Index, Scalar, Series, _Frame
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\core.py", line 52, in <module>
#     from .accessor import DatetimeAccessor, StringAccessor
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\accessor.py", line 109, in <module>
#     class StringAccessor(Accessor):
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\accessor.py", line 121, in StringAccessor
#     @derived_from(pd.core.strings.StringMethods)
# AttributeError: module 'pandas.core.strings' has no attribute 'StringMethods'
# Repeating k-fold bagging: 2/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 883.42s of the 3283.67s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-129.0218	 = Validation score   (-root_mean_squared_error)
# 	56.1s	 = Training   runtime
# 	0.75s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 855.46s of the 3255.71s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-151.7125	 = Validation score   (-root_mean_squared_error)
# 	94.84s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 815.44s of the 3215.69s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-139.6093	 = Validation score   (-root_mean_squared_error)
# 	470.63s	 = Training   runtime
# 	0.71s	 = Validation runtime
# Repeating k-fold bagging: 3/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 572.97s of the 2973.22s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-127.4783	 = Validation score   (-root_mean_squared_error)
# 	84.09s	 = Training   runtime
# 	1.12s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 544.43s of the 2944.68s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-150.6118	 = Validation score   (-root_mean_squared_error)
# 	137.87s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 500.88s of the 2901.13s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-138.833	 = Validation score   (-root_mean_squared_error)
# 	713.67s	 = Training   runtime
# 	1.14s	 = Validation runtime
# Completed 3/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 2657.58s of remaining time.
# 	-122.3713	 = Validation score   (-root_mean_squared_error)
# 	0.14s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1180.78s of the 2657.41s of remaining time.
# 	Warning: Exception caused LightGBMXT_BAG_L2 to fail during training... Skipping this model.
# 		module 'pandas.core.strings' has no attribute 'StringMethods'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1422, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1367, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\abstract\abstract_model.py", line 628, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 154, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 236, in _fit
#     self._fit_folds(X=X, y=y, model_base=model_base, X_pseudo=X_pseudo, y_pseudo=y_pseudo,
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 500, in _fit_folds
#     fold_fitting_strategy = fold_fitting_strategy(**fold_fitting_strategy_args)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 148, in __init__
#     minimum_model_resources = self._initialized_model_base.get_minimum_resources(
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\tabular\models\lgb\lgb_model.py", line 352, in get_minimum_resources
#     if is_gpu_available and self._is_gpu_lgbm_installed():
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\tabular\models\lgb\lgb_model.py", line 336, in _is_gpu_lgbm_installed
#     try_import_lightgbm()
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\utils\try_import.py", line 157, in try_import_lightgbm
#     import lightgbm
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\basic.py", line 20, in <module>
#     from .compat import PANDAS_INSTALLED, concat, dt_DataTable, is_dtype_sparse, pd_DataFrame, pd_Series
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\compat.py", line 130, in <module>
#     from dask.dataframe import DataFrame as dask_DataFrame
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\__init__.py", line 3, in <module>
#     from . import backends, dispatch, rolling
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\backends.py", line 20, in <module>
#     from .core import DataFrame, Index, Scalar, Series, _Frame
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\core.py", line 52, in <module>
#     from .accessor import DatetimeAccessor, StringAccessor
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\accessor.py", line 109, in <module>
#     class StringAccessor(Accessor):
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\accessor.py", line 121, in StringAccessor
#     @derived_from(pd.core.strings.StringMethods)
# AttributeError: module 'pandas.core.strings' has no attribute 'StringMethods'
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1180.76s of the 2657.39s of remaining time.
# 	Warning: Exception caused LightGBM_BAG_L2 to fail during training... Skipping this model.
# 		module 'pandas.core.strings' has no attribute 'StringMethods'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1422, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1367, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\abstract\abstract_model.py", line 628, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 154, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 236, in _fit
#     self._fit_folds(X=X, y=y, model_base=model_base, X_pseudo=X_pseudo, y_pseudo=y_pseudo,
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 500, in _fit_folds
#     fold_fitting_strategy = fold_fitting_strategy(**fold_fitting_strategy_args)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 148, in __init__
#     minimum_model_resources = self._initialized_model_base.get_minimum_resources(
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\tabular\models\lgb\lgb_model.py", line 352, in get_minimum_resources
#     if is_gpu_available and self._is_gpu_lgbm_installed():
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\tabular\models\lgb\lgb_model.py", line 336, in _is_gpu_lgbm_installed
#     try_import_lightgbm()
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\utils\try_import.py", line 157, in try_import_lightgbm
#     import lightgbm
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\basic.py", line 20, in <module>
#     from .compat import PANDAS_INSTALLED, concat, dt_DataTable, is_dtype_sparse, pd_DataFrame, pd_Series
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\compat.py", line 130, in <module>
#     from dask.dataframe import DataFrame as dask_DataFrame
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\__init__.py", line 3, in <module>
#     from . import backends, dispatch, rolling
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\backends.py", line 20, in <module>
#     from .core import DataFrame, Index, Scalar, Series, _Frame
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\core.py", line 52, in <module>
#     from .accessor import DatetimeAccessor, StringAccessor
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\accessor.py", line 109, in <module>
#     class StringAccessor(Accessor):
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\accessor.py", line 121, in StringAccessor
#     @derived_from(pd.core.strings.StringMethods)
# AttributeError: module 'pandas.core.strings' has no attribute 'StringMethods'
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 1180.73s of the 2657.37s of remaining time.
# 	-126.8909	 = Validation score   (-root_mean_squared_error)
# 	0.59s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1179.87s of the 2656.5s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	Warning: Exception caused CatBoost_BAG_L2 to fail during training (ImportError)... Skipping this model.
# 		`import catboost` failed. A quick tip is to install via `pip install autogluon.tabular[catboost]==0.6.0`.
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 1179.85s of the 2656.48s of remaining time.
# 	-124.7915	 = Validation score   (-root_mean_squared_error)
# 	0.32s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1179.26s of the 2655.89s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 2: early stopping
# No improvement since epoch 8: early stopping
# No improvement since epoch 1: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 7: early stopping
# 	-125.9655	 = Validation score   (-root_mean_squared_error)
# 	22.33s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1156.34s of the 2632.97s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-127.8585	 = Validation score   (-root_mean_squared_error)
# 	10.76s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1145.36s of the 2621.99s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-137.0674	 = Validation score   (-root_mean_squared_error)
# 	90.69s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1054.21s of the 2530.84s of remaining time.
# 	Warning: Exception caused LightGBMLarge_BAG_L2 to fail during training... Skipping this model.
# 		module 'pandas.core.strings' has no attribute 'StringMethods'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1422, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1367, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\abstract\abstract_model.py", line 628, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 154, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 236, in _fit
#     self._fit_folds(X=X, y=y, model_base=model_base, X_pseudo=X_pseudo, y_pseudo=y_pseudo,
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 500, in _fit_folds
#     fold_fitting_strategy = fold_fitting_strategy(**fold_fitting_strategy_args)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 148, in __init__
#     minimum_model_resources = self._initialized_model_base.get_minimum_resources(
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\tabular\models\lgb\lgb_model.py", line 352, in get_minimum_resources
#     if is_gpu_available and self._is_gpu_lgbm_installed():
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\tabular\models\lgb\lgb_model.py", line 336, in _is_gpu_lgbm_installed
#     try_import_lightgbm()
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\utils\try_import.py", line 157, in try_import_lightgbm
#     import lightgbm
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\basic.py", line 20, in <module>
#     from .compat import PANDAS_INSTALLED, concat, dt_DataTable, is_dtype_sparse, pd_DataFrame, pd_Series
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\compat.py", line 130, in <module>
#     from dask.dataframe import DataFrame as dask_DataFrame
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\__init__.py", line 3, in <module>
#     from . import backends, dispatch, rolling
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\backends.py", line 20, in <module>
#     from .core import DataFrame, Index, Scalar, Series, _Frame
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\core.py", line 52, in <module>
#     from .accessor import DatetimeAccessor, StringAccessor
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\accessor.py", line 109, in <module>
#     class StringAccessor(Accessor):
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\accessor.py", line 121, in StringAccessor
#     @derived_from(pd.core.strings.StringMethods)
# AttributeError: module 'pandas.core.strings' has no attribute 'StringMethods'
# Repeating k-fold bagging: 2/20
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1054.18s of the 2530.81s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 2: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 8: early stopping
# 	-123.3102	 = Validation score   (-root_mean_squared_error)
# 	46.5s	 = Training   runtime
# 	0.8s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1029.43s of the 2506.06s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-127.4597	 = Validation score   (-root_mean_squared_error)
# 	21.42s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1018.53s of the 2495.16s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-135.4095	 = Validation score   (-root_mean_squared_error)
# 	179.17s	 = Training   runtime
# 	0.8s	 = Validation runtime
# Repeating k-fold bagging: 3/20
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 929.56s of the 2406.19s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 4: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 1: early stopping
# 	-122.5187	 = Validation score   (-root_mean_squared_error)
# 	68.76s	 = Training   runtime
# 	1.18s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 906.73s of the 2383.36s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-126.63	 = Validation score   (-root_mean_squared_error)
# 	32.29s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 895.65s of the 2372.28s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-134.2459	 = Validation score   (-root_mean_squared_error)
# 	270.52s	 = Training   runtime
# 	1.19s	 = Validation runtime
# Repeating k-fold bagging: 4/20
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 803.82s of the 2280.45s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 2: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 1: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 4: early stopping
# 	-122.1827	 = Validation score   (-root_mean_squared_error)
# 	90.79s	 = Training   runtime
# 	1.59s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 781.19s of the 2257.82s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-126.7507	 = Validation score   (-root_mean_squared_error)
# 	43.04s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 770.21s of the 2246.84s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-134.3953	 = Validation score   (-root_mean_squared_error)
# 	359.2s	 = Training   runtime
# 	1.58s	 = Validation runtime
# Repeating k-fold bagging: 5/20
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 681.07s of the 2157.7s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 2: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 1: early stopping
# No improvement since epoch 4: early stopping
# 	-122.0784	 = Validation score   (-root_mean_squared_error)
# 	113.03s	 = Training   runtime
# 	1.98s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 658.26s of the 2134.89s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-127.0417	 = Validation score   (-root_mean_squared_error)
# 	53.81s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 647.26s of the 2123.89s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-134.5482	 = Validation score   (-root_mean_squared_error)
# 	445.03s	 = Training   runtime
# 	1.96s	 = Validation runtime
# Repeating k-fold bagging: 6/20
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 560.97s of the 2037.6s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 4: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 9: early stopping
# No improvement since epoch 1: early stopping
# No improvement since epoch 1: early stopping
# 	-121.9663	 = Validation score   (-root_mean_squared_error)
# 	135.09s	 = Training   runtime
# 	2.37s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 538.34s of the 2014.97s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-126.8053	 = Validation score   (-root_mean_squared_error)
# 	64.55s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 527.37s of the 2004.0s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-134.6726	 = Validation score   (-root_mean_squared_error)
# 	527.88s	 = Training   runtime
# 	2.34s	 = Validation runtime
# Repeating k-fold bagging: 7/20
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 444.03s of the 1920.66s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 4: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 2: early stopping
# 	-121.9914	 = Validation score   (-root_mean_squared_error)
# 	157.68s	 = Training   runtime
# 	2.74s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 420.88s of the 1897.52s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-126.8068	 = Validation score   (-root_mean_squared_error)
# 	75.19s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 410.0s of the 1886.63s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-134.5057	 = Validation score   (-root_mean_squared_error)
# 	627.0s	 = Training   runtime
# 	2.72s	 = Validation runtime
# Repeating k-fold bagging: 8/20
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 310.42s of the 1787.05s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 3: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 2: early stopping
# 	-121.7592	 = Validation score   (-root_mean_squared_error)
# 	179.5s	 = Training   runtime
# 	3.14s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 288.03s of the 1764.67s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-126.6666	 = Validation score   (-root_mean_squared_error)
# 	86.27s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 276.73s of the 1753.36s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-134.1328	 = Validation score   (-root_mean_squared_error)
# 	710.11s	 = Training   runtime
# 	3.08s	 = Validation runtime
# Repeating k-fold bagging: 9/20
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 193.17s of the 1669.81s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 2: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 8: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 9: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 2: early stopping
# 	-121.7777	 = Validation score   (-root_mean_squared_error)
# 	201.9s	 = Training   runtime
# 	3.55s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 170.18s of the 1646.81s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-126.743	 = Validation score   (-root_mean_squared_error)
# 	97.13s	 = Training   runtime
# 	0.52s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 159.1s of the 1635.73s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-134.1426	 = Validation score   (-root_mean_squared_error)
# 	807.27s	 = Training   runtime
# 	3.44s	 = Validation runtime
# Completed 9/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 1538.11s of remaining time.
# 	-121.5711	 = Validation score   (-root_mean_squared_error)
# 	0.1s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L3 models ...
# Fitting model: LightGBMXT_BAG_L3 ... Training model for up to 1025.07s of the 1537.99s of remaining time.
# 	Warning: Exception caused LightGBMXT_BAG_L3 to fail during training... Skipping this model.
# 		module 'pandas.core.strings' has no attribute 'StringMethods'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1422, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1367, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\abstract\abstract_model.py", line 628, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 154, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 236, in _fit
#     self._fit_folds(X=X, y=y, model_base=model_base, X_pseudo=X_pseudo, y_pseudo=y_pseudo,
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 500, in _fit_folds
#     fold_fitting_strategy = fold_fitting_strategy(**fold_fitting_strategy_args)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 148, in __init__
#     minimum_model_resources = self._initialized_model_base.get_minimum_resources(
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\tabular\models\lgb\lgb_model.py", line 352, in get_minimum_resources
#     if is_gpu_available and self._is_gpu_lgbm_installed():
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\tabular\models\lgb\lgb_model.py", line 336, in _is_gpu_lgbm_installed
#     try_import_lightgbm()
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\utils\try_import.py", line 157, in try_import_lightgbm
#     import lightgbm
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\basic.py", line 20, in <module>
#     from .compat import PANDAS_INSTALLED, concat, dt_DataTable, is_dtype_sparse, pd_DataFrame, pd_Series
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\compat.py", line 130, in <module>
#     from dask.dataframe import DataFrame as dask_DataFrame
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\__init__.py", line 3, in <module>
#     from . import backends, dispatch, rolling
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\backends.py", line 20, in <module>
#     from .core import DataFrame, Index, Scalar, Series, _Frame
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\core.py", line 52, in <module>
#     from .accessor import DatetimeAccessor, StringAccessor
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\accessor.py", line 109, in <module>
#     class StringAccessor(Accessor):
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\accessor.py", line 121, in StringAccessor
#     @derived_from(pd.core.strings.StringMethods)
# AttributeError: module 'pandas.core.strings' has no attribute 'StringMethods'
# Fitting model: LightGBM_BAG_L3 ... Training model for up to 1025.04s of the 1537.95s of remaining time.
# ...
#     import lightgbm
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\basic.py", line 20, in <module>
#     from .compat import PANDAS_INSTALLED, concat, dt_DataTable, is_dtype_sparse, pd_DataFrame, pd_Series
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\compat.py", line 130, in <module>
#     from dask.dataframe import DataFrame as dask_DataFrame
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\__init__.py", line 3, in <module>
#     from . import backends, dispatch, rolling
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\backends.py", line 20, in <module>
#     from .core import DataFrame, Index, Scalar, Series, _Frame
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\core.py", line 52, in <module>
#     from .accessor import DatetimeAccessor, StringAccessor
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\accessor.py", line 109, in <module>
#     class StringAccessor(Accessor):
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\accessor.py", line 121, in StringAccessor
#     @derived_from(pd.core.strings.StringMethods)
# AttributeError: module 'pandas.core.strings' has no attribute 'StringMethods'
# Fitting model: LightGBM_BAG_L4 ... Training model for up to 581.32s of the 581.31s of remaining time.
# 	Warning: Exception caused LightGBM_BAG_L4 to fail during training... Skipping this model.
# 		module 'pandas.core.strings' has no attribute 'StringMethods'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1422, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1367, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\abstract\abstract_model.py", line 628, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 154, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 236, in _fit
#     self._fit_folds(X=X, y=y, model_base=model_base, X_pseudo=X_pseudo, y_pseudo=y_pseudo,
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 500, in _fit_folds
#     fold_fitting_strategy = fold_fitting_strategy(**fold_fitting_strategy_args)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 148, in __init__
#     minimum_model_resources = self._initialized_model_base.get_minimum_resources(
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\tabular\models\lgb\lgb_model.py", line 352, in get_minimum_resources
#     if is_gpu_available and self._is_gpu_lgbm_installed():
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\tabular\models\lgb\lgb_model.py", line 336, in _is_gpu_lgbm_installed
#     try_import_lightgbm()
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\utils\try_import.py", line 157, in try_import_lightgbm
#     import lightgbm
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\basic.py", line 20, in <module>
#     from .compat import PANDAS_INSTALLED, concat, dt_DataTable, is_dtype_sparse, pd_DataFrame, pd_Series
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\compat.py", line 130, in <module>
#     from dask.dataframe import DataFrame as dask_DataFrame
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\__init__.py", line 3, in <module>
#     from . import backends, dispatch, rolling
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\backends.py", line 20, in <module>
#     from .core import DataFrame, Index, Scalar, Series, _Frame
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\core.py", line 52, in <module>
#     from .accessor import DatetimeAccessor, StringAccessor
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\accessor.py", line 109, in <module>
#     class StringAccessor(Accessor):
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\accessor.py", line 121, in StringAccessor
#     @derived_from(pd.core.strings.StringMethods)
# AttributeError: module 'pandas.core.strings' has no attribute 'StringMethods'
# Fitting model: RandomForestMSE_BAG_L4 ... Training model for up to 581.29s of the 581.29s of remaining time.
# 	-128.0157	 = Validation score   (-root_mean_squared_error)
# 	0.54s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: CatBoost_BAG_L4 ... Training model for up to 580.46s of the 580.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	Warning: Exception caused CatBoost_BAG_L4 to fail during training (ImportError)... Skipping this model.
# 		`import catboost` failed. A quick tip is to install via `pip install autogluon.tabular[catboost]==0.6.0`.
# Fitting model: ExtraTreesMSE_BAG_L4 ... Training model for up to 580.43s of the 580.43s of remaining time.
# 	-127.7741	 = Validation score   (-root_mean_squared_error)
# 	0.33s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L4 ... Training model for up to 579.85s of the 579.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 5: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 9: early stopping
# No improvement since epoch 6: early stopping
# 	-128.1727	 = Validation score   (-root_mean_squared_error)
# 	24.3s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: XGBoost_BAG_L4 ... Training model for up to 554.96s of the 554.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-134.2028	 = Validation score   (-root_mean_squared_error)
# 	10.62s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L4 ... Training model for up to 544.1s of the 544.09s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-143.7315	 = Validation score   (-root_mean_squared_error)
# 	82.76s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L4 ... Training model for up to 460.86s of the 460.86s of remaining time.
# 	Warning: Exception caused LightGBMLarge_BAG_L4 to fail during training... Skipping this model.
# 		module 'pandas.core.strings' has no attribute 'StringMethods'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1422, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1367, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\abstract\abstract_model.py", line 628, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 154, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 236, in _fit
#     self._fit_folds(X=X, y=y, model_base=model_base, X_pseudo=X_pseudo, y_pseudo=y_pseudo,
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 500, in _fit_folds
#     fold_fitting_strategy = fold_fitting_strategy(**fold_fitting_strategy_args)
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 148, in __init__
#     minimum_model_resources = self._initialized_model_base.get_minimum_resources(
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\tabular\models\lgb\lgb_model.py", line 352, in get_minimum_resources
#     if is_gpu_available and self._is_gpu_lgbm_installed():
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\tabular\models\lgb\lgb_model.py", line 336, in _is_gpu_lgbm_installed
#     try_import_lightgbm()
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\autogluon\core\utils\try_import.py", line 157, in try_import_lightgbm
#     import lightgbm
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\basic.py", line 20, in <module>
#     from .compat import PANDAS_INSTALLED, concat, dt_DataTable, is_dtype_sparse, pd_DataFrame, pd_Series
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\lightgbm\compat.py", line 130, in <module>
#     from dask.dataframe import DataFrame as dask_DataFrame
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\__init__.py", line 3, in <module>
#     from . import backends, dispatch, rolling
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\backends.py", line 20, in <module>
#     from .core import DataFrame, Index, Scalar, Series, _Frame
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\core.py", line 52, in <module>
#     from .accessor import DatetimeAccessor, StringAccessor
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\accessor.py", line 109, in <module>
#     class StringAccessor(Accessor):
#   File "C:\Users\User\AppData\Roaming\Python\Python38\site-packages\dask\dataframe\accessor.py", line 121, in StringAccessor
#     @derived_from(pd.core.strings.StringMethods)
# AttributeError: module 'pandas.core.strings' has no attribute 'StringMethods'
# Repeating k-fold bagging: 2/20
# Fitting model: NeuralNetFastAI_BAG_L4 ... Training model for up to 460.83s of the 460.83s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 5: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 3: early stopping
# 	-125.5639	 = Validation score   (-root_mean_squared_error)
# 	47.74s	 = Training   runtime
# 	0.81s	 = Validation runtime
# Fitting model: XGBoost_BAG_L4 ... Training model for up to 436.83s of the 436.83s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-131.3908	 = Validation score   (-root_mean_squared_error)
# 	21.15s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L4 ... Training model for up to 426.11s of the 426.1s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-142.713	 = Validation score   (-root_mean_squared_error)
# 	168.87s	 = Training   runtime
# 	0.76s	 = Validation runtime
# Repeating k-fold bagging: 3/20
# Fitting model: NeuralNetFastAI_BAG_L4 ... Training model for up to 339.54s of the 339.53s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 2: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 5: early stopping
# 	-124.5467	 = Validation score   (-root_mean_squared_error)
# 	70.24s	 = Training   runtime
# 	1.19s	 = Validation runtime
# Fitting model: XGBoost_BAG_L4 ... Training model for up to 316.46s of the 316.46s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-131.3208	 = Validation score   (-root_mean_squared_error)
# 	31.67s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L4 ... Training model for up to 305.72s of the 305.72s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-141.9733	 = Validation score   (-root_mean_squared_error)
# 	248.49s	 = Training   runtime
# 	1.17s	 = Validation runtime
# Repeating k-fold bagging: 4/20
# Fitting model: NeuralNetFastAI_BAG_L4 ... Training model for up to 225.59s of the 225.59s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 2: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 3: early stopping
# 	-123.9772	 = Validation score   (-root_mean_squared_error)
# 	93.38s	 = Training   runtime
# 	1.6s	 = Validation runtime
# Fitting model: XGBoost_BAG_L4 ... Training model for up to 201.84s of the 201.84s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-130.7958	 = Validation score   (-root_mean_squared_error)
# 	42.19s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L4 ... Training model for up to 191.06s of the 191.06s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	-141.8671	 = Validation score   (-root_mean_squared_error)
# 	331.22s	 = Training   runtime
# 	1.57s	 = Validation runtime
# Completed 4/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L5 ... Training model for up to 360.0s of the 107.82s of remaining time.
# 	-123.6215	 = Validation score   (-root_mean_squared_error)
# 	0.12s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 3492.33s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20230930_021527\")

# %% [markdown]
# # Inference / 추론

# %%
print(predictor.leaderboard(silent = True))
# Out:
#                      model   score_val  pred_time_val     fit_time
# 0      WeightedEnsemble_L3 -121.571063       7.304684  1236.380791  \
# 1   NeuralNetFastAI_BAG_L2 -121.777652       6.424649  1138.232935
# 2      WeightedEnsemble_L2 -122.371272       2.489990   935.776309
# 3      WeightedEnsemble_L4 -122.549777      14.034612  2226.043240
# 4   NeuralNetFastAI_BAG_L3 -123.601617      13.864613  2225.410239
# 5      WeightedEnsemble_L5 -123.621480      19.526532  3083.405011
# 6   NeuralNetFastAI_BAG_L4 -123.977172      19.356532  3082.747011
# 7     ExtraTreesMSE_BAG_L2 -124.791474       3.055035   936.658302
# 8   RandomForestMSE_BAG_L3 -125.538774      10.918646  2044.078336
# 9     ExtraTreesMSE_BAG_L3 -126.317820      10.916646  2043.874335
# 10          XGBoost_BAG_L2 -126.742956       3.402039  1033.463162
# 11  RandomForestMSE_BAG_L2 -126.890902       3.060065   936.925305
# 12          XGBoost_BAG_L3 -127.223658      11.226654  2128.905087
# 13  NeuralNetFastAI_BAG_L1 -127.478336       1.119975    84.087040
# 14    ExtraTreesMSE_BAG_L4 -127.774054      17.929558  2989.692052
# 15  RandomForestMSE_BAG_L4 -128.015719      17.929558  2989.901052
# 16          XGBoost_BAG_L4 -130.795837      18.007554  3031.552416
# 17   NeuralNetTorch_BAG_L2 -134.142596       6.322997  1743.608851
# 18   NeuralNetTorch_BAG_L1 -138.833044       1.138002   713.674197
# 19   NeuralNetTorch_BAG_L3 -140.005596      13.827587  2721.300398
# 20   NeuralNetTorch_BAG_L4 -141.867134      19.332974  3320.584198
# 21          XGBoost_BAG_L1 -150.611803       0.232012   137.871072
# 22  RandomForestMSE_BAG_L1 -181.258435       0.168030     0.376997
# 23    ExtraTreesMSE_BAG_L1 -201.368787       0.168012     0.316000
# 24   KNeighborsUnif_BAG_L1 -306.588586       0.030001     0.005000
# 25   KNeighborsDist_BAG_L1 -309.945562       0.023002     0.004000
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer
# 0                 0.000000           0.104002            3       True  \
# 1                 3.545615         201.898630            2       True
# 2                 0.000000           0.144001            2       True
# 3                 0.000000           0.106000            4       True
# 4                 3.115966         181.858904            3       True
# 5                 0.000000           0.120000            5       True
# 6                 1.596973          93.383958            4       True
# 7                 0.176001           0.323997            2       True
# 8                 0.169999           0.527000            3       True
# 9                 0.167999           0.322999            3       True
# 10                0.523004          97.128857            2       True
# 11                0.181030           0.591000            2       True
# 12                0.478007          85.353751            3       True
# 13                1.119975          84.087040            1       True
# 14                0.169999           0.329000            4       True
# 15                0.170000           0.538000            4       True
# 16                0.247995          42.189364            4       True
# 17                3.443962         807.274546            2       True
# 18                1.138002         713.674197            1       True
# 19                3.078940         677.749063            3       True
# 20                1.573415         331.221145            4       True
# 21                0.232012         137.871072            1       True
# 22                0.168030           0.376997            1       True
# 23                0.168012           0.316000            1       True
# 24                0.030001           0.005000            1       True
# 25                0.023002           0.004000            1       True
#
#     fit_order
# 0          14
# 1          11
# 2           8
# 3          20
# 4          17
# 5          26
# 6          23
# 7          10
# 8          15
# 9          16
# 10         12
# 11          9
# 12         18
# 13          5
# 14         22
# 15         21
# 16         24
# 17         13
# 18          7
# 19         19
# 20         25
# 21          6
# 22          3
# 23          4
# 24          1
# 25          2

# %%
predictor.get_model_best()
# Out:
# 'WeightedEnsemble_L3'

# %%
model_to_use = predictor.get_model_best()
model_pred = predictor.predict(test_data, model=model_to_use)

# %% [markdown]
# # submit / 제출

# %%
submission = pd.read_csv('sample_submission.csv')

# %%
submission['수요량'] = model_pred

# %%
submission.to_csv('./submit_autogluon.csv', index = False)
